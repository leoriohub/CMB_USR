# %% [markdown]
# # Phase 1.2 - Full P_S(k) Scan
#
# Goal: compute and characterize P_S(k) for golden trajectories.
#
# TODO:
# - Load golden_trajectories.json.
# - Run scripts/pspectrum_pipeline.py for each trajectory.
# - Plot P_S(k) and quantify dip amplitude/location/width.

# %%
# Imports and setup

# %%
# Load golden trajectories and run P_S(k) pipeline

# %%
# Plot P_S(k) and compute dip metrics

# %% [markdown]
# # Phase 1.1 - Background Survey
#
# Goal: map (phi0, yi, xi) to USR duration and find golden trajectories.
#
# TODO:
# - Define parameter grids for phi0, yi, xi.
# - Run background simulations for each grid point.
# - Compute epsilon2 and USR duration.
# - Plot heatmaps and mark golden trajectories.
# - Save golden trajectories to get_path("configs", make_filename("config", 5.40, -0.050, 60)).

# %%
# Imports and setup

# %%
# Define parameter grids (phi0, yi, xi)

# %%
# Run background simulations and compute USR duration

# %%
# Plot heatmaps and identify golden trajectories
